# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
airbnb_df = pd.read_csv('Chicago_Airbnb_Listing_Dataset.csv')
airbnb_df.head()
# Out:
#       id neighbourhood_cleansed  latitude  longitude        room_type  \
# 0   2384              Hyde Park  41.78790  -87.58780     Private room
# 1   7126              West Town  41.90166  -87.68021  Entire home/apt
# 2  10945           Lincoln Park  41.91196  -87.63981  Entire home/apt
# 3  12140           Lincoln Park  41.92357  -87.64947     Private room
# 4  22362              West Town  41.89730  -87.65889  Entire home/apt
#
#    accommodates  bathrooms_text  bedrooms  beds     price  minimum_nights  \
# 0             1   1 shared bath       1.0   1.0   $95.00                3
# 1             2          1 bath       1.0   1.0   $65.00                2
# 2             4          1 bath       2.0   2.0  $127.00                4
# 3             2  1 private bath       1.0   2.0  $329.00                2
# 4             4         2 baths       2.0   2.0  $105.00              121
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              89                       3                       3
# 1              60                       2                       2
# 2             180                       4                       4
# 3               7                       2                       2
# 4            1125                     121                     121
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                     3.0
# 1                    1125                    1125                     2.0
# 2                     180                     180                     4.0
# 3                       7                       7                     2.0
# 4                    1125                    1125                   121.0
#
#    maximum_nights_avg_ntm
# 0                  1125.0
# 1                  1125.0
# 2                   180.0
# 3                     7.0
# 4                  1125.0

# %%
airbnb_df['price'] = airbnb_df['price'].str.replace('$', '')
airbnb_df['price'] = airbnb_df['price'].str.replace(',', '').astype(float)
# Out:
# C:\Users\Rus\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
airbnb_df.drop(airbnb_df[airbnb_df.price > 1000].index, inplace=True)

# %%
airbnb_df.head()
# Out:
#       id neighbourhood_cleansed  latitude  longitude        room_type  \
# 0   2384              Hyde Park  41.78790  -87.58780     Private room
# 1   7126              West Town  41.90166  -87.68021  Entire home/apt
# 2  10945           Lincoln Park  41.91196  -87.63981  Entire home/apt
# 3  12140           Lincoln Park  41.92357  -87.64947     Private room
# 4  22362              West Town  41.89730  -87.65889  Entire home/apt
#
#    accommodates  bathrooms_text  bedrooms  beds  price  minimum_nights  \
# 0             1   1 shared bath       1.0   1.0   95.0               3
# 1             2          1 bath       1.0   1.0   65.0               2
# 2             4          1 bath       2.0   2.0  127.0               4
# 3             2  1 private bath       1.0   2.0  329.0               2
# 4             4         2 baths       2.0   2.0  105.0             121
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0              89                       3                       3
# 1              60                       2                       2
# 2             180                       4                       4
# 3               7                       2                       2
# 4            1125                     121                     121
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                     3.0
# 1                    1125                    1125                     2.0
# 2                     180                     180                     4.0
# 3                       7                       7                     2.0
# 4                    1125                    1125                   121.0
#
#    maximum_nights_avg_ntm
# 0                  1125.0
# 1                  1125.0
# 2                   180.0
# 3                     7.0
# 4                  1125.0

# %%
X = pd.get_dummies(working_df)
X
# Out:
#       latitude  longitude  price  minimum_nights  number_of_reviews  \
# 0     41.78790  -87.58780     60               2                178
# 1     41.85495  -87.69696    105               2                395
# 2     41.90289  -87.68182     60               2                384
# 3     41.91769  -87.63788     65               4                 49
# 4     41.79612  -87.59261     21               1                 44
# ...        ...        ...    ...             ...                ...
# 6392  41.85574  -87.62507    146               2                  0
# 6393  41.85561  -87.62342    195               2                  0
# 6394  41.85584  -87.62404    493               2                  0
# 6395  41.89005  -87.66668     53              32                  0
# 6396  41.82964  -87.62048     61               1                  0
#
#       calculated_host_listings_count  availability_365  \
# 0                                  1               353
# 1                                  1               155
# 2                                  1               321
# 3                                  9               300
# 4                                  5               168
# ...                              ...               ...
# 6392                               4               180
# 6393                               4               180
# 6394                               4               177
# 6395                               1                83
# 6396                               1               170
#
#       room_type_Entire home/apt  room_type_Hotel room  room_type_Private room  \
# 0                             0                     0                       1
# 1                             1                     0                       0
# 2                             1                     0                       0
# 3                             1                     0                       0
# 4                             0                     0                       1
# ...                         ...                   ...                     ...
# 6392                          1                     0                       0
# 6393                          1                     0                       0
# 6394                          1                     0                       0
# 6395                          0                     0                       1
# 6396                          1                     0                       0
#
#       room_type_Shared room
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
# ...                     ...
# 6392                      0
# 6393                      0
# 6394                      0
# 6395                      0
# 6396                      0
#
# [6397 rows x 11 columns]

# %%
X = X.drop('price', axis=1)
y = airbnb_df.price

# %%
X_scaled = StandardScaler().fit_transform(X)
X_scaled
# Out:
# array([[-1.88632217,  1.79769864, -0.26829748, ..., -0.10743988,
#          1.577944  , -0.11945651],
#        [-0.74841388, -0.77616029, -0.26829748, ..., -0.10743988,
#         -0.63373605, -0.11945651],
#        [ 0.06517781, -0.41917766, -0.26829748, ..., -0.10743988,
#         -0.63373605, -0.11945651],
#        ...,
#        [-0.73330966,  0.94320388, -0.26829748, ..., -0.10743988,
#         -0.63373605, -0.11945651],
#        [-0.15273035, -0.06219503,  1.04835391, ..., -0.10743988,
#          1.577944  , -0.11945651],
#        [-1.17795093,  1.02714432, -0.31218586, ..., -0.10743988,
#         -0.63373605, -0.11945651]])

# %%
model = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.005901109980655739
